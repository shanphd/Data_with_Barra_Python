# %% [markdown]
# ## Sting in Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Count 

text = '''
Python is good
Python is Awesome 
python is ml
''' 

print(text.count('Python'))
print (text.count("python"))b
# Out:
# 2
# 1

# %% [markdown]
# # Transformations

# %%
# Replace 

name = 'Shan'
Role = 'Data Scientist'
Dob = '28/08/1989'
phone_number = "+91.866783.2430" 

print(Dob.replace ('/', '-'))
print (phone_number.replace('.', ''))
# Out:
# 28-08-1989
# +918667832430

# %%
# Concatenation

folder = "c:/users/shan"
file = "Datascientist.csv"

# we can use + symbol to contacentae 

full_path = folder + "/" + file
print(full_path)
# Out:
# c:/users/shan/Datascientist.csv

# %%
# f string Formatted String 

folder = "c:/users/shan"
file = "Datascientist.csv"

full_Path = f"{folder}/{file}"
print(full_Path)

# To add variable inside f string 

add = f"2 + 2 = {2 + 2}"
print (add)

# worng print(f"{My name is shan}")
print (f"My name is {Role}")
# Out:
# c:/users/shan/Datascientist.csv
# 2 + 2 = 4
# My name is Data Scientist

# %%
# Split 

csv_file = 'shan, 28.08.1989,8667832430'
print(csv_file.split(','))

# * 

print("#" * 20)
print(f"My name is shan")
# Out:
# ['shan', ' 28.08.1989', '8667832430']
# ####################
# My name is shan

# %% [markdown]
# # Need to continue index and slicing
